# %%
#Upload files
import pandas as pd
df = pd.read_csv(r"C:\Users\Hasya-ZanrooMY\OneDrive\Desktop\Nexpert_Hackathon\Datasets\spam.csv", encoding="latin-1")

# %%
import pandas as pd
import pickle

with open("logistic_model.pkl", "rb") as f:
    model = pickle.load(f)

with open("tfidf_vectorizer.pkl", "rb") as f:
    vectorizer = pickle.load(f)

# %%
sample_text = ["Congratulations! You won a free prize, click now"]
sample_vec = vectorizer.transform(sample_text)
prediction = model.predict(sample_vec)

print(prediction)
# Out:
# [1]
