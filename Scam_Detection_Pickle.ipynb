# %%
import pickle

# load model
with open("fraud_model_lr.pkl", "rb") as f:
    loaded_model = pickle.load(f)

# test prediction
test_text = ["Win RM5000 now!!! Click here"]
print(loaded_model.predict(test_text))
# Out:
# ['fraud']
